# %%
import os
import glob

path_train="data/custom/train.txt"
os.remove(path_train)
path_valid="data/custom/valid.txt"
os.remove(path_valid)

files=(glob.glob('data/custom/images/*')


for file in sorted(files[:670]):
    f = open(path_train, 'a') # 書き込みモードで開く
    f.write(file+"\n") # 引数の文字列をファイルに書き込む
    f.close()

for file in sorted(files[670:]):
    f = open(path_valid, 'a') # 書き込みモードで開く
    f.write(file+"\n") # 引数の文字列をファイルに書き込む
    f.close()

# %%
with open(path, "r") as file:
    img_files = file.readlines()

# %%
import glob
glob.glob('data/custom/images/*')
# Out:
# ['data/custom/images/image_765.png',
#  'data/custom/images/image_637.png',
#  'data/custom/images/image_200.png',
#  'data/custom/images/image_340.png',
#  'data/custom/images/image_681.png',
#  'data/custom/images/image_367.png',
#  'data/custom/images/image_747.png',
#  'data/custom/images/image_372.png',
#  'data/custom/images/image_787.png',
#  'data/custom/images/image_080.png',
#  'data/custom/images/image_426.png',
#  'data/custom/images/image_537.png',
#  'data/custom/images/image_263.png',
#  'data/custom/images/image_281.png',
#  'data/custom/images/image_104.png',
#  'data/custom/images/image_121.png',
#  'data/custom/images/image_773.png',
#  'data/custom/images/image_261.png',
#  'data/custom/images/image_616.png',
#  'data/custom/images/image_505.png',
#  'data/custom/images/image_319.png',
#  'data/custom/images/image_782.png',
#  'data/custom/images/image_398.png',
#  'data/custom/images/image_723.png',
#  'data/custom/images/image_771.png',
# ...

# %%
img_path = img_files[1].rstrip()

# %%
img_path
# Out:
# 'data/custom/images/image_001.png'

# %%
import numpy as np
np.loadtxt("data/custom/labels/image_000.txt")
# Out:
# array([[0.        , 0.73377404, 0.60456731, 0.26802885, 0.27644231],
#        [0.        , 0.23918269, 0.74639423, 0.28365385, 0.29567308],
#        [0.        , 0.75240385, 0.76081731, 0.30048077, 0.29086538],
#        [0.        , 0.90384615, 0.85637019, 0.19230769, 0.28725962],
#        [1.        , 0.86418269, 0.54807692, 0.27163462, 0.40144231],
#        [1.        , 0.21814904, 0.56850962, 0.24879808, 0.22596154],
#        [1.        , 0.44110577, 0.57211538, 0.28605769, 0.26442308],
#        [1.        , 0.45913462, 0.79747596, 0.37019231, 0.35216346],
#        [0.        , 0.37860577, 0.01502404, 0.14903846, 0.03004808],
#        [0.        , 0.37199519, 0.07151442, 0.27524038, 0.14302885],
#        [0.        , 0.5       , 0.36418269, 0.25240385, 0.23557692],
#        [0.        , 0.19110577, 0.32572115, 0.29807692, 0.31490385],
#        [0.        , 0.66346154, 0.01983173, 0.09855769, 0.03966346],
#        [1.        , 0.86237981, 0.30408654, 0.27524038, 0.39423077],
# ...

# %%
import numpy as np
import torch
boxes = torch.from_numpy(np.loadtxt("data/custom/labels/image_000.txt").reshape(-1, 5))
